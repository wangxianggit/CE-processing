// %%
#include "cali.h"
#include <iostream>
#include <map>

using namespace std;

// %%
//get data from 335 file
TFile *ipf = new TFile("./spulse00335.root");
TTree *tree = (TTree*)ipf->Get("tree");
TCanvas *c1=new TCanvas("c1","c1");
Double_t e;
ULong64_t ts;
Int_t fr,str,det;
tree->SetBranchAddress("e",&e);
tree->SetBranchAddress("ts",&ts);
tree->SetBranchAddress("fr",&fr);
tree->SetBranchAddress("str",&str);
tree->SetBranchAddress("det",&det);
tree->Print();
// Out:
// ******************************************************************************
// *Tree    :tree      : tree                                                   *
// *Entries :    84952 : Total =      2304364310 bytes  File  Size =  465434707 *
// *        :          : Tree compression factor =   4.95                       *
// ******************************************************************************
// *Br    0 :det       : det/I                                                  *
// *Entries :    84952 : Total  Size=     341815 bytes  File Size  =       3656 *
// *Baskets :       19 : Basket Size=      51200 bytes  Compression=  93.31     *
// *............................................................................*
// *Br    1 :fr        : fr/I                                                   *
// *Entries :    84952 : Total  Size=     341792 bytes  File Size  =       3637 *
// *Baskets :       19 : Basket Size=      51200 bytes  Compression=  93.79     *
// *............................................................................*
// *Br    2 :str       : str/I                                                  *
// *Entries :    84952 : Total  Size=     341815 bytes  File Size  =      42372 *
// *Baskets :       19 : Basket Size=      51200 bytes  Compression=   8.05     *
// *............................................................................*
// *Br    3 :ts        : ts/l                                                   *
// *Entries :    84952 : Total  Size=     681697 bytes  File Size  =     375992 *
// *Baskets :       20 : Basket Size=      64512 bytes  Compression=   1.81     *
// *............................................................................*
// *Br    4 :er        : er/D                                                   *
// *Entries :    84952 : Total  Size=     681697 bytes  File Size  =     359181 *
// *Baskets :       20 : Basket Size=      64512 bytes  Compression=   1.90     *
// *............................................................................*
// *Br    5 :e         : e/D                                                    *
// *Entries :    84952 : Total  Size=     681673 bytes  File Size  =     623606 *
// *Baskets :       20 : Basket Size=      64512 bytes  Compression=   1.09     *
// *............................................................................*
// *Br    6 :fe        : fe/D                                                   *
// *Entries :    84952 : Total  Size=     681697 bytes  File Size  =       4988 *
// *Baskets :       20 : Basket Size=      64512 bytes  Compression= 136.53     *
// *............................................................................*
// *Br    7 :ip        : ip/I                                                   *
// *Entries :    84952 : Total  Size=     341792 bytes  File Size  =       3911 *
// *Baskets :       19 : Basket Size=      51200 bytes  Compression=  87.22     *
// *............................................................................*
// *Br    8 :np        : np/I                                                   *
// *Entries :    84952 : Total  Size=     341792 bytes  File Size  =       3637 *
// *Baskets :       19 : Basket Size=      51200 bytes  Compression=  93.79     *
// *............................................................................*
// *Br    9 :ep        : ep[np]/D                                               *
// *Entries :    84952 : Total  Size=    1703203 bytes  File Size  =     799260 *
// *Baskets :       39 : Basket Size=     103936 bytes  Compression=   2.13     *
// *............................................................................*
// *Br   10 :fep       : fep[np]/D                                              *
// *Entries :    84952 : Total  Size=    1703246 bytes  File Size  =     106753 *
// *Baskets :       39 : Basket Size=     103936 bytes  Compression=  15.94     *
// *............................................................................*
// *Br   11 :epw       : epw[np]/D                                              *
// *Entries :    84952 : Total  Size=    1703246 bytes  File Size  =     191227 *
// *Baskets :       39 : Basket Size=     103936 bytes  Compression=   8.90     *
// *............................................................................*
// *Br   12 :tsp       : tsp[np]/l                                              *
// *Entries :    84952 : Total  Size=    1703246 bytes  File Size  =     644208 *
// *Baskets :       39 : Basket Size=     103936 bytes  Compression=   2.64     *
// *............................................................................*
// *Br   13 :tsw       : tsw/I                                                  *
// *Entries :    84952 : Total  Size=     341815 bytes  File Size  =       3418 *
// *Baskets :       19 : Basket Size=      51200 bytes  Compression=  99.81     *
// *............................................................................*
// *Br   14 :dwave     : dwave[750]/D                                           *
// *Entries :    84952 : Total  Size=  509801931 bytes  File Size  =   87031549 *
// *Baskets :      974 : Basket Size=   25600000 bytes  Compression=   5.86     *
// *............................................................................*
// *Br   15 :rwave     : rwave[750]/S                                           *
// *Entries :    84952 : Total  Size=  127452139 bytes  File Size  =   23274057 *
// *Baskets :      259 : Basket Size=    4993024 bytes  Compression=   5.48     *
// *............................................................................*
// *Br   16 :sample    : sample[750]/S                                          *
// *Entries :    84952 : Total  Size=  127452402 bytes  File Size  =    1287667 *
// *Baskets :      259 : Basket Size=    4993024 bytes  Compression=  98.98     *
// *............................................................................*
// *Br   17 :chi2      : chi2[np]/D                                             *
// *Entries :    84952 : Total  Size=    1703289 bytes  File Size  =     833706 *
// *Baskets :       39 : Basket Size=     103936 bytes  Compression=   2.04     *
// *............................................................................*
// *Br   18 :trapezoidE : trapezoidE/D                                          *
// *Entries :    84952 : Total  Size=     681889 bytes  File Size  =     345754 *
// *Baskets :       20 : Basket Size=      64512 bytes  Compression=   1.97     *
// *............................................................................*
// *Br   19 :chi       : chi/D                                                  *
// *Entries :    84952 : Total  Size=     681721 bytes  File Size  =     648274 *
// *Baskets :       20 : Basket Size=      64512 bytes  Compression=   1.05     *
// *............................................................................*
// *Br   20 :para      : para[10]/D                                             *
// *Entries :    84952 : Total  Size=    6800754 bytes  File Size  =    1249776 *
// *Baskets :       47 : Basket Size=     302080 bytes  Compression=   5.44     *
// *............................................................................*
// *Br   21 :ndf       : ndf/I                                                  *
// *Entries :    84952 : Total  Size=     341815 bytes  File Size  =      21862 *
// *Baskets :       19 : Basket Size=      51200 bytes  Compression=  15.60     *
// *............................................................................*
// *Br   22 :flu       : flu/D                                                  *
// *Entries :    84952 : Total  Size=     681721 bytes  File Size  =     287335 *
// *Baskets :       20 : Basket Size=      64512 bytes  Compression=   2.37     *
// *............................................................................*
// *Br   23 :chi2h     : chi2h/D                                                *
// *Entries :    84952 : Total  Size=     681769 bytes  File Size  =       6053 *
// *Baskets :       20 : Basket Size=      64512 bytes  Compression= 112.52     *
// *............................................................................*
// *Br   24 :flu       : flu/D                                                  *
// *Entries :    84952 : Total  Size=     681721 bytes  File Size  =     287335 *
// *Baskets :       20 : Basket Size=      64512 bytes  Compression=   2.37     *
// *............................................................................*
// *Br   25 :fwave     : fwave[730]/D                                           *
// *Entries :    84952 : Total  Size=  496209611 bytes  File Size  =  187875199 *
// *Baskets :      974 : Basket Size=   25600000 bytes  Compression=   2.64     *
// *............................................................................*
// *Br   26 :trap      : trap[750]/D                                            *
// *Entries :    84952 : Total  Size=  509800953 bytes  File Size  =   56452073 *
// *Baskets :      974 : Basket Size=   25600000 bytes  Compression=   9.03     *
// *............................................................................*
// *Br   27 :trap1     : trap1[750]/D                                           *
// *Entries :    84952 : Total  Size=  509801931 bytes  File Size  =  102625638 *
// *Baskets :      974 : Basket Size=   25600000 bytes  Compression=   4.97     *
// *............................................................................*

// %%
tree->Draw("e>>h(200,10,15000)","det==2");
c1->Draw();

// %% [markdown]
// ## amplitude from front and back sides

// %%
tree->Draw("e:str>>h(128,0,128,1000,0,10000)","fr==2","colz");
c1->Draw();

// %%
tree->Draw("e:str>>h(48,0,48,1000,0,10000)","fr==1","colz");
c1->Draw();

// %%
//events sort and output variable
struct dect {
    Int_t str;
    Double_t e;
    ULong64_t ts;
};

multimap<ULong64_t, dect> mapts_f,mapts_b,mapts_mw,mapts_ve;
multimap<ULong64_t, dect>::iterator its,jts;
dect dts;

// %%
for(Int_t i=0;i<tree->GetEntriesFast();i++){
    tree->GetEntry(i);
    if(det==4) continue;
    dts.str=str;
    dts.e=e;
    dts.ts=ts;
    if(det==1) mapts_mw.insert(pair<ULong64_t,dect> (ts,dts));
    if(det==2&&fr==1) mapts_f.insert(pair<ULong64_t,dect> (ts,dts));
    if(det==2&&fr==2) mapts_b.insert(pair<ULong64_t,dect> (ts,dts));
    if(det==3) mapts_ve.insert(pair<ULong64_t,dect> (ts,dts));
    if(i%10000==0) cout<<"*";
    //if(i<100)cout<<ts<<"  "<<det<<"  "<<fr<<"  "<<str<<"  "<<e<<endl;
}
cout<<endl;
cout<<" Total events:"<<mapts_f.size()<<"  "<<mapts_b.size()<<endl;
cout<<" size mwpc:"<<mapts_mw.size()<<"  "<<"size veto:"<<mapts_ve.size()<<endl;
ipf->Close();
// Out:
// *********
//  Total events:0  84952
//  size mwpc:0  size veto:0

// %%
//check the events 
its = mapts_f.begin();
for(Int_t i=0;i<10;i++){
    cout<<its->first<<"  "<<its->second.e<<"  "<<its->second.str<<endl;
    its++;
    break;
}

// %%
//time difference between dssd and mwpc
ULong64_t twin=10000;
TH1F *thdt = new TH1F("thdt","time difference between dssd and mwpc",1000,-1000,1000);
for(its=mapts_b.begin();its!=mapts_b.end();its++){
    for(jts=mapts_mw.lower_bound(its->first-twin);jts!=mapts_mw.end();jts++){
        if(its->first+twin<jts->first) break;
        Int_t dt = jts->first-its->first;
        thdt->Fill(dt);
        jts++;
    }
}
thdt->Draw();
c1->SetLogy();
c1->Draw();
TTree *opt = new TTree("tree","tree");

// %%
void BranchOpt(){
  opt->Branch("xhit",&xhit,"xhit/I");
  opt->Branch("yhit",&yhit,"yhit/I");
  opt->Branch("x",&x,"x[xhit]/I");
  opt->Branch("y",&y,"y[yhit]/I");
  opt->Branch("xe",&xe,"xe[xhit]/D");
  opt->Branch("ye",&ye,"ye[yhit]/D");
  opt->Branch("xt",&xt,"xt[xhit]/l");
  opt->Branch("yt",&yt,"yt[yhit]/l");
  opt->Branch("ve",ve,"ve[3]/D");
  opt->Branch("vt",vt,"vt[3]/D");
  opt->Branch("mwe",&mwe,"mwe/D");
  opt->Branch("mwt",&mwt,"mwt/l");
}

// %%
//event calssification and time sort
TFile *otf = new TFile("sort00335.root","recreate");
twin=500;
BranchOpt();
Int_t count=0;
for(its=mapts_b.begin();its!=mapts_b.end();its++){
    ResetOpt();
    
    x[xhit]=its->second.str;
    xt[xhit]=its->first;
    xe[xhit]=its->second.e;
    xhit++;
    for(jts=mapts_b.lower_bound(its->first-twin);jts!=mapts_b.end();jts++){
        if(its->first+twin<jts->first) break;
        if(xhit>10) continue;
        if(its->first==jts->first)continue;
        x[xhit]=jts->second.str;
        xt[xhit]=jts->first;
        xe[xhit]=jts->second.e;
        xhit++;        
    }    
    
    for(jts=mapts_f.lower_bound(its->first-twin);jts!=mapts_f.end();jts++){
        if(its->first+twin<jts->first) break;
        if(yhit>10) continue;
        y[yhit]=jts->second.str;
        yt[yhit]=jts->first;
        ye[yhit]=jts->second.e;
        yhit++;          
    }
    
    for(jts=mapts_mw.lower_bound(its->first-twin);jts!=mapts_mw.end();jts++){
        if(its->first+twin<jts->first) break;
        mwe=jts->second.e;
        mwt=jts->first;
    }

    for(jts=mapts_ve.lower_bound(its->first-twin);jts!=mapts_ve.end();jts++){
        if(its->first+twin<jts->first) break;
        Int_t n;
        n=jts->second.str;
        ve[n]=jts->second.e;
        vt[n]=jts->first;
    }
    opt->Fill();
    if(count<10) cout<<x[0]<<"  "<<y[0]<<endl;
    count++;
    if(count%4000==0) cout<<" "<<count;
}
opt->Write();
otf->Close();
cout<<" file done!"<<endl;
// Out:
// 55  0
// 55  0
// 48  0
// 48  0
// 76  0
// 77  0
// 77  0
// 76  0
// 79  0
// 79  0
//  4000 8000 12000 16000 20000 24000 28000 32000 36000 40000 44000 48000 52000 56000 60000 64000 68000 72000 76000 80000 84000 file done!
